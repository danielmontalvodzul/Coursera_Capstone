# %% [markdown]
# # Proyecto Capstone - La Batalla de los Vecindarios

# %% [markdown]
# Se busca mejorar la inversión en el ámbito inmobiliario en Argentina, para esto queremos encontrar las provincias que han tenido mayor auge en este sector. Contamos con 2 bases de datos proporcionadas por datos.gob.ar. La primera nos da informacion de los ultimos desarrollos realizados en Argetina y la segunda son las 24 pronvincias que tiene el país.

# %%
import numpy as np  # librería para manejar datos vectorizados
import pandas as pd # librería para procesar datos como dataframes

# %%
import matplotlib.pyplot as plt #librería para graficar
# %matplotlib inline

# %%
# librería para manejar archivos JSON 
import json 

#!conda install -c conda-forge geopy --yes # retirar el comentario de esta línea si no ha completado el laboratorio de la API de FourSquare 
from geopy.geocoders import Nominatim # convertir una dirección en valores de latitud y longitud

import requests # librería para manejar solicitudes
from pandas.io.json import json_normalize # librería para convertir un archivo json en un dataframe pandas

# Matplotlib y módulos asociados para graficar
import matplotlib.cm as cm
import matplotlib.colors as colors

# importar k-means desde la fase de agrupación
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin_min

#!conda install -c conda-forge folium=0.5.0 --yes # retirar el comentario de esta línea si no ha completado el laboratorio de la API de FourSquare
import folium # librería para graficar mapas 

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
desarrollos=pd.read_csv("https://infra.datos.gob.ar/catalog/modernizacion/dataset/7/distribution/7.29/download/localidades-censales.csv")
provincias=pd.read_csv("https://infra.datos.gob.ar/catalog/modernizacion/dataset/7/distribution/7.7/download/provincias.csv")

# %% [markdown]
# Se tienen 3326 desarrollos realizados en los ultimos años en Argentina

# %%
desarrollos
# Out:
#                               categoria  centroide_lat  centroide_lon  \
# 0                      Localidad simple     -37.823387     -60.484640
# 1                      Localidad simple     -37.625498     -58.746186
# 2                      Localidad simple     -37.542635     -58.340719
# 3                      Localidad simple     -38.012284     -58.355378
# 4                      Localidad simple     -37.859629     -57.980601
# ...                                 ...            ...            ...
# 3521  Componente de localidad compuesta     -26.815571     -65.269158
# 3522                   Localidad simple     -54.637686     -67.766941
# 3523                   Localidad simple     -54.803640     -68.316062
# 3524                   Localidad simple     -53.787047     -67.713235
# 3525                   Localidad simple     -54.511387     -67.195804
#
#       departamento_id     departamento_nombre fuente                funcion  \
# 0              6014.0  Adolfo Gonzales Chaves  INDEC                    NaN
# 1              6063.0                Balcarce  INDEC                    NaN
# 2              6063.0                Balcarce  INDEC                    NaN
# 3              6063.0                Balcarce  INDEC                    NaN
# 4              6063.0                Balcarce  INDEC                    NaN
# ...               ...                     ...    ...                    ...
# 3521          90119.0             Yerba Buena  INDEC  CABECERA_DEPARTAMENTO
# 3522          94015.0                 Ushuaia  INDEC                    NaN
# 3523          94015.0                 Ushuaia  INDEC      CAPITAL_PROVINCIA
# 3524          94008.0              Río Grande  INDEC  CABECERA_DEPARTAMENTO
# 3525          94008.0              Río Grande  INDEC                    NaN
#
#             id  municipio_id              municipio_nombre  \
# 0      6014030       60014.0        Adolfo Gonzales Chaves
# 1      6063030       60063.0                      Balcarce
# 2      6063040       60063.0                      Balcarce
# 3      6063050       60063.0                      Balcarce
# 4      6063060       60063.0                      Balcarce
# ...        ...           ...                           ...
# 3521  90119030      908560.0  Municipalidad de Yerba Buena
# 3522  94015010           NaN                           NaN
# 3523  94015020      940014.0                       Ushuaia
# 3524  94008010      940007.0                    Río Grande
# 3525  94008020      942007.0                       Tolhuin
#
#                         nombre  provincia_id  \
# 0                Juan E. Barra             6
# 1                    Napaleofú             6
# 2                  Ramos Otero             6
# 3                  San Agustín             6
# 4        Villa Laguna La Brava             6
# ...                        ...           ...
# 3521  Yerba Buena - Marcos Paz            90
# 3522          Laguna Escondida            94
# 3523                   Ushuaia            94
# 3524                Río Grande            94
# 3525                   Tolhuin            94
#
#                                        provincia_nombre
# 0                                          Buenos Aires
# 1                                          Buenos Aires
# 2                                          Buenos Aires
# 3                                          Buenos Aires
# 4                                          Buenos Aires
# ...                                                 ...
# 3521                                            Tucumán
# 3522  Tierra del Fuego, Antártida e Islas del Atlánt...
# 3523  Tierra del Fuego, Antártida e Islas del Atlánt...
# 3524  Tierra del Fuego, Antártida e Islas del Atlánt...
# 3525  Tierra del Fuego, Antártida e Islas del Atlánt...
#
# [3526 rows x 13 columns]

# %%
provincias
# Out:
#           categoria  centroide_lat  centroide_lon fuente  id iso_id  \
# 0         Provincia     -26.875397     -54.651697    IGN  54   AR-N
# 1         Provincia     -33.757726     -66.028130    IGN  74   AR-D
# 2         Provincia     -30.865368     -68.889491    IGN  70   AR-J
# 3         Provincia     -32.058874     -59.201448    IGN  30   AR-E
# 4         Provincia     -48.815485     -69.955762    IGN  78   AR-Z
# 5         Provincia     -40.405796     -67.229330    IGN  62   AR-R
# 6         Provincia     -43.788623     -68.526759    IGN  26   AR-U
# 7         Provincia     -32.142933     -63.801753    IGN  14   AR-X
# 8         Provincia     -34.629887     -68.583123    IGN  50   AR-M
# 9         Provincia     -29.685776     -67.181736    IGN  46   AR-F
# 10        Provincia     -27.335833     -66.947682    IGN  10   AR-K
# 11        Provincia     -37.131554     -65.446655    IGN  42   AR-L
# 12        Provincia     -27.782412     -63.252387    IGN  86   AR-G
# 13        Provincia     -28.774305     -57.801219    IGN  18   AR-W
# 14        Provincia     -30.706927     -60.949837    IGN  82   AR-S
# 15        Provincia     -26.947800     -65.364758    IGN  90   AR-T
# 16        Provincia     -38.641758     -70.118571    IGN  58   AR-Q
# 17        Provincia     -24.299134     -64.814463    IGN  66   AR-A
# 18        Provincia     -26.386431     -60.765831    IGN  22   AR-H
# 19        Provincia     -24.894973     -59.932441    IGN  34   AR-P
# 20        Provincia     -23.320078     -65.764252    IGN  38   AR-Y
# 21  Ciudad Autónoma     -34.614493     -58.445856    IGN   2   AR-C
# 22        Provincia     -36.676942     -60.558832    IGN   6   AR-B
# 23        Provincia     -82.521518     -50.742749    IGN  94   AR-V
#
#                          iso_nombre  \
# 0                          Misiones
# 1                          San Luis
# 2                          San Juan
# 3                        Entre Ríos
# 4                        Santa Cruz
# 5                         Río Negro
# 6                            Chubut
# 7                           Córdoba
# 8                           Mendoza
# 9                          La Rioja
# 10                        Catamarca
# 11                         La Pampa
# 12              Santiago del Estero
# 13                       Corrientes
# 14                         Santa Fe
# 15                          Tucumán
# 16                          Neuquén
# 17                            Salta
# 18                            Chaco
# 19                          Formosa
# 20                            Jujuy
# 21  Ciudad Autónoma de Buenos Aires
# 22                     Buenos Aires
# 23                 Tierra del Fuego
#
#                                                nombre  \
# 0                                            Misiones
# 1                                            San Luis
# 2                                            San Juan
# 3                                          Entre Ríos
# 4                                          Santa Cruz
# 5                                           Río Negro
# 6                                              Chubut
# 7                                             Córdoba
# 8                                             Mendoza
# 9                                            La Rioja
# 10                                          Catamarca
# 11                                           La Pampa
# 12                                Santiago del Estero
# 13                                         Corrientes
# 14                                           Santa Fe
# 15                                            Tucumán
# 16                                            Neuquén
# 17                                              Salta
# 18                                              Chaco
# 19                                            Formosa
# 20                                              Jujuy
# 21                    Ciudad Autónoma de Buenos Aires
# 22                                       Buenos Aires
# 23  Tierra del Fuego, Antártida e Islas del Atlánt...
#
#                                       nombre_completo
# 0                               Provincia de Misiones
# 1                               Provincia de San Luis
# 2                               Provincia de San Juan
# 3                             Provincia de Entre Ríos
# 4                             Provincia de Santa Cruz
# 5                              Provincia de Río Negro
# 6                                Provincia del Chubut
# 7                                Provincia de Córdoba
# 8                                Provincia de Mendoza
# 9                               Provincia de La Rioja
# 10                             Provincia de Catamarca
# 11                              Provincia de La Pampa
# 12                   Provincia de Santiago del Estero
# 13                            Provincia de Corrientes
# 14                              Provincia de Santa Fe
# 15                               Provincia de Tucumán
# 16                              Provincia del Neuquén
# 17                                 Provincia de Salta
# 18                                Provincia del Chaco
# 19                               Provincia de Formosa
# 20                                 Provincia de Jujuy
# 21                    Ciudad Autónoma de Buenos Aires
# 22                          Provincia de Buenos Aires
# 23  Provincia de Tierra del Fuego, Antártida e Isl...

# %% [markdown]
# De los desarrollos, los agrupamos por Provincia y contamos el numero de desarrollos que se tienen en cada una de ellas

# %%
regiones=pd.DataFrame(desarrollos.groupby(["provincia_nombre"]).size(),columns=['num_desarrollos']).sort_values(by="num_desarrollos")
regiones["Provincias"]=regiones.index
regiones
# Out:
#                                                     num_desarrollos  \
# provincia_nombre
# Ciudad Autónoma de Buenos Aires                                   1
# Tierra del Fuego, Antártida e Islas del Atlánti...                4
# Santa Cruz                                                       27
# Neuquén                                                          60
# Formosa                                                          62
# Chubut                                                           69
# La Rioja                                                         73
# Corrientes                                                       77
# San Juan                                                         82
# San Luis                                                         85
# La Pampa                                                         89
# Chaco                                                            91
# Tucumán                                                          98
# Salta                                                           130
# Misiones                                                        139
# Río Negro                                                       149
# Jujuy                                                           151
# Mendoza                                                         152
# Catamarca                                                       154
# Santiago del Estero                                             165
# Entre Ríos                                                      169
# Santa Fe                                                        383
# Córdoba                                                         523
# Buenos Aires                                                    593
#
#                                                                                            Provincias
# provincia_nombre
# Ciudad Autónoma de Buenos Aires                                       Ciudad Autónoma de Buenos Aires
# Tierra del Fuego, Antártida e Islas del Atlánti...  Tierra del Fuego, Antártida e Islas del Atlánt...
# Santa Cruz                                                                                 Santa Cruz
# Neuquén                                                                                       Neuquén
# Formosa                                                                                       Formosa
# Chubut                                                                                         Chubut
# La Rioja                                                                                     La Rioja
# Corrientes                                                                                 Corrientes
# San Juan                                                                                     San Juan
# San Luis                                                                                     San Luis
# La Pampa                                                                                     La Pampa
# Chaco                                                                                           Chaco
# Tucumán                                                                                       Tucumán
# Salta                                                                                           Salta
# Misiones                                                                                     Misiones
# Río Negro                                                                                   Río Negro
# Jujuy                                                                                           Jujuy
# Mendoza                                                                                       Mendoza
# Catamarca                                                                                   Catamarca
# Santiago del Estero                                                               Santiago del Estero
# Entre Ríos                                                                                 Entre Ríos
# Santa Fe                                                                                     Santa Fe
# Córdoba                                                                                       Córdoba
# Buenos Aires                                                                             Buenos Aires

# %% [markdown]
# A la base de Provincias, la unimos con la base que tiene el numero de desarrollos

# %%
geo_prov=regiones.merge(provincias,left_on="Provincias",right_on="nombre")
geo_prov.sort_values(by="num_desarrollos")
# Out:
#     num_desarrollos                                         Provincias  \
# 0                 1                    Ciudad Autónoma de Buenos Aires
# 1                 4  Tierra del Fuego, Antártida e Islas del Atlánt...
# 2                27                                         Santa Cruz
# 3                60                                            Neuquén
# 4                62                                            Formosa
# 5                69                                             Chubut
# 6                73                                           La Rioja
# 7                77                                         Corrientes
# 8                82                                           San Juan
# 9                85                                           San Luis
# 10               89                                           La Pampa
# 11               91                                              Chaco
# 12               98                                            Tucumán
# 13              130                                              Salta
# 14              139                                           Misiones
# 15              149                                          Río Negro
# 16              151                                              Jujuy
# 17              152                                            Mendoza
# 18              154                                          Catamarca
# 19              165                                Santiago del Estero
# 20              169                                         Entre Ríos
# 21              383                                           Santa Fe
# 22              523                                            Córdoba
# 23              593                                       Buenos Aires
#
#           categoria  centroide_lat  centroide_lon fuente  id iso_id  \
# 0   Ciudad Autónoma     -34.614493     -58.445856    IGN   2   AR-C
# 1         Provincia     -82.521518     -50.742749    IGN  94   AR-V
# 2         Provincia     -48.815485     -69.955762    IGN  78   AR-Z
# 3         Provincia     -38.641758     -70.118571    IGN  58   AR-Q
# 4         Provincia     -24.894973     -59.932441    IGN  34   AR-P
# 5         Provincia     -43.788623     -68.526759    IGN  26   AR-U
# 6         Provincia     -29.685776     -67.181736    IGN  46   AR-F
# 7         Provincia     -28.774305     -57.801219    IGN  18   AR-W
# 8         Provincia     -30.865368     -68.889491    IGN  70   AR-J
# 9         Provincia     -33.757726     -66.028130    IGN  74   AR-D
# 10        Provincia     -37.131554     -65.446655    IGN  42   AR-L
# 11        Provincia     -26.386431     -60.765831    IGN  22   AR-H
# 12        Provincia     -26.947800     -65.364758    IGN  90   AR-T
# 13        Provincia     -24.299134     -64.814463    IGN  66   AR-A
# 14        Provincia     -26.875397     -54.651697    IGN  54   AR-N
# 15        Provincia     -40.405796     -67.229330    IGN  62   AR-R
# 16        Provincia     -23.320078     -65.764252    IGN  38   AR-Y
# 17        Provincia     -34.629887     -68.583123    IGN  50   AR-M
# 18        Provincia     -27.335833     -66.947682    IGN  10   AR-K
# 19        Provincia     -27.782412     -63.252387    IGN  86   AR-G
# 20        Provincia     -32.058874     -59.201448    IGN  30   AR-E
# 21        Provincia     -30.706927     -60.949837    IGN  82   AR-S
# 22        Provincia     -32.142933     -63.801753    IGN  14   AR-X
# 23        Provincia     -36.676942     -60.558832    IGN   6   AR-B
#
#                          iso_nombre  \
# 0   Ciudad Autónoma de Buenos Aires
# 1                  Tierra del Fuego
# 2                        Santa Cruz
# 3                           Neuquén
# 4                           Formosa
# 5                            Chubut
# 6                          La Rioja
# 7                        Corrientes
# 8                          San Juan
# 9                          San Luis
# 10                         La Pampa
# 11                            Chaco
# 12                          Tucumán
# 13                            Salta
# 14                         Misiones
# 15                        Río Negro
# 16                            Jujuy
# 17                          Mendoza
# 18                        Catamarca
# 19              Santiago del Estero
# 20                       Entre Ríos
# 21                         Santa Fe
# 22                          Córdoba
# 23                     Buenos Aires
#
#                                                nombre  \
# 0                     Ciudad Autónoma de Buenos Aires
# 1   Tierra del Fuego, Antártida e Islas del Atlánt...
# 2                                          Santa Cruz
# 3                                             Neuquén
# 4                                             Formosa
# 5                                              Chubut
# 6                                            La Rioja
# 7                                          Corrientes
# 8                                            San Juan
# 9                                            San Luis
# 10                                           La Pampa
# 11                                              Chaco
# 12                                            Tucumán
# 13                                              Salta
# 14                                           Misiones
# 15                                          Río Negro
# 16                                              Jujuy
# 17                                            Mendoza
# 18                                          Catamarca
# 19                                Santiago del Estero
# 20                                         Entre Ríos
# 21                                           Santa Fe
# 22                                            Córdoba
# 23                                       Buenos Aires
#
#                                       nombre_completo
# 0                     Ciudad Autónoma de Buenos Aires
# 1   Provincia de Tierra del Fuego, Antártida e Isl...
# 2                             Provincia de Santa Cruz
# 3                               Provincia del Neuquén
# 4                                Provincia de Formosa
# 5                                Provincia del Chubut
# 6                               Provincia de La Rioja
# 7                             Provincia de Corrientes
# 8                               Provincia de San Juan
# 9                               Provincia de San Luis
# 10                              Provincia de La Pampa
# 11                                Provincia del Chaco
# 12                               Provincia de Tucumán
# 13                                 Provincia de Salta
# 14                              Provincia de Misiones
# 15                             Provincia de Río Negro
# 16                                 Provincia de Jujuy
# 17                               Provincia de Mendoza
# 18                             Provincia de Catamarca
# 19                   Provincia de Santiago del Estero
# 20                            Provincia de Entre Ríos
# 21                              Provincia de Santa Fe
# 22                               Provincia de Córdoba
# 23                          Provincia de Buenos Aires

# %%
mayor_municipio=geo_prov.loc[[19,20,21,22,23]]
mayor_municipio=mayor_municipio.drop(["categoria","nombre","fuente","id","iso_id","nombre_completo","Provincias"],axis=1)
mayor_municipio.reset_index(drop=True,inplace=True)
mayor_municipio.rename(columns={"iso_nombre": "Provincia", "B": "c"},inplace=True)

# %%
address = 'Argentina'

geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Argentina are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Argentina are -34.9964963, -64.9672817.

# %%
map_costa = folium.Map(location=[latitude, longitude], zoom_start=4)

# añadir los marcadores al mapa
for lat, lng, label in zip(mayor_municipio['centroide_lat'], mayor_municipio['centroide_lon'], mayor_municipio['Provincia']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=8,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_costa)  
    
map_costa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;style&gt; #map_ce96e74c79a6895b81ee3b0fe8b13e43 {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce96e74c79a6895b81ee3b0fe8b13e43&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#
#
#                 var bounds = null;
#
#
#             var map_ce96e74c79a6895b81ee3b0fe8b13e43 = L.map(
#                                   &#x27;map_ce96e74c79a6895b81ee3b0fe8b13e43&#x27;,
#                                   {center: [-34.9964963,-64.9672817],
#                                   zoom: 4,
#                                   maxBounds: bounds,
#                                   layers: [],
#                                   worldCopyJump: false,
#                                   crs: L.CRS.EPSG3857
#                                  });
#
#
#
#             var tile_layer_5ec04173141ea3bf460a09328709d1f3 = L.tileLayer(
#                 &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#                 {
#   &quot;attribution&quot;: null,
#   &quot;detectRetina&quot;: false,
#   &quot;maxZoom&quot;: 18,
#   &quot;minZoom&quot;: 1,
#   &quot;noWrap&quot;: false,
#   &quot;subdomains&quot;: &quot;abc&quot;
# }
#                 ).addTo(map_ce96e74c79a6895b81ee3b0fe8b13e43);
#
#
#             var circle_marker_7ded6417f462326717e5a2ca2a2d65fe = L.circleMarker(
#                 [-27.7824116550944,-63.2523866568588],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;blue&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3186cc&quot;,
#   &quot;fillOpacity&quot;: 0.7,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 8,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 ).addTo(map_ce96e74c79a6895b81ee3b0fe8b13e43);
#
#
#             var popup_bd77940b8c851e9cba4a9b1235722cf0 = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_be133c4a98eb88ffbbd8df3734fc33b9 = $(&#x27;&lt;div id=&quot;html_be133c4a98eb88ffbbd8df3734fc33b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Santiago del Estero&lt;/div&gt;&#x27;)[0];
#                 popup_bd77940b8c851e9cba4a9b1235722cf0.setContent(html_be133c4a98eb88ffbbd8df3734fc33b9);
#
#
#             circle_marker_7ded6417f462326717e5a2ca2a2d65fe.bindPopup(popup_bd77940b8c851e9cba4a9b1235722cf0);
#
#
#
#
#             var circle_marker_d4b1f93b1c89f10a562bf7a32268dbab = L.circleMarker(
#                 [-32.0588735436448,-59.2014475514635],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;blue&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3186cc&quot;,
#   &quot;fillOpacity&quot;: 0.7,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 8,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 ).addTo(map_ce96e74c79a6895b81ee3b0fe8b13e43);
#
#
#             var popup_a7da4d847c0dfe2353ee16792086658f = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_02c5e0652d15c1e92968a21727a0cb79 = $(&#x27;&lt;div id=&quot;html_02c5e0652d15c1e92968a21727a0cb79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Entre Ríos&lt;/div&gt;&#x27;)[0];
#                 popup_a7da4d847c0dfe2353ee16792086658f.setContent(html_02c5e0652d15c1e92968a21727a0cb79);
#
#
#             circle_marker_d4b1f93b1c89f10a562bf7a32268dbab.bindPopup(popup_a7da4d847c0dfe2353ee16792086658f);
#
#
#
#
#             var circle_marker_5ec46772c8fe994bb01e43152c73da6c = L.circleMarker(
#                 [-30.7069271588117,-60.9498369430241],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;blue&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3186cc&quot;,
#   &quot;fillOpacity&quot;: 0.7,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 8,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 ).addTo(map_ce96e74c79a6895b81ee3b0fe8b13e43);
#
#
#             var popup_df4d7a7a338da3499ff165367c0805e7 = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_af923a040b75849564da4968f85c9322 = $(&#x27;&lt;div id=&quot;html_af923a040b75849564da4968f85c9322&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Santa Fe&lt;/div&gt;&#x27;)[0];
#                 popup_df4d7a7a338da3499ff165367c0805e7.setContent(html_af923a040b75849564da4968f85c9322);
#
#
#             circle_marker_5ec46772c8fe994bb01e43152c73da6c.bindPopup(popup_df4d7a7a338da3499ff165367c0805e7);
#
#
#
#
#             var circle_marker_8d0941fd7b070538eb8434e75c5227ba = L.circleMarker(
#                 [-32.142932663607,-63.8017532741662],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;blue&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3186cc&quot;,
#   &quot;fillOpacity&quot;: 0.7,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 8,
#   &quo

# %% [markdown]
# Y finalmente graficamos los 5 municipios con mayor numero de desarrollos en los ultimos años.
